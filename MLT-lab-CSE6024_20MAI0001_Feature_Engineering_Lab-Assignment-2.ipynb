# %% [markdown]
# MLT-Lab-CSE6024_Lab-Assignment-2: Feature Engineering
#
# Submitted By: 20MAI0001 - NIHARIKA MAITRA
#
# Git Repo link :  https://github.com/Niharika-20-MAI-01/Winter-2021-MLTechniques-LabCSE6024-Niharika-20MAI01/blob/main/MLT-lab-CSE6024_20MAI0001_Feature_Engineering_Lab-Assignment-2.ipynb

# %%
#Importing necessay Libraries and Packages
import pandas as pd
import numpy as np
import datetime

# %% [markdown]
# Performing Feature Engineering on crx.data dataset

# %%
#Loading the data to DataFrame using Pandas
data = pd.read_csv('crx.data', header = None)

# %% [markdown]
# 1.	In the dataset crx.data, name the columns as col1, col2..col16

# %%
# Applying Variable Engineering or Feature Engineering to 
#Rename the Columns of crx.data dataset as col1,col2,...col16
varnames = ['Col'+ str(s) for s in range(1,17)]

# %%
#To add the new column names
data.columns = varnames

# %%
#To view the first 20 rows of dataset 
data.head(20)
# Out:
#    Col1   Col2    Col3 Col4 Col5 Col6 Col7   Col8 Col9 Col10  Col11 Col12  \
# 0     b  30.83   0.000    u    g    w    v  1.250    t     t      1     f
# 1     a  58.67   4.460    u    g    q    h  3.040    t     t      6     f
# 2     a  24.50   0.500    u    g    q    h  1.500    t     f      0     f
# 3     b  27.83   1.540    u    g    w    v  3.750    t     t      5     t
# 4     b  20.17   5.625    u    g    w    v  1.710    t     f      0     f
# 5     b  32.08   4.000    u    g    m    v  2.500    t     f      0     t
# 6     b  33.17   1.040    u    g    r    h  6.500    t     f      0     t
# 7     a  22.92  11.585    u    g   cc    v  0.040    t     f      0     f
# 8     b  54.42   0.500    y    p    k    h  3.960    t     f      0     f
# 9     b  42.50   4.915    y    p    w    v  3.165    t     f      0     t
# 10    b  22.08   0.830    u    g    c    h  2.165    f     f      0     t
# 11    b  29.92   1.835    u    g    c    h  4.335    t     f      0     f
# ...

# %% [markdown]
# 2.	Print the last 10 rows of data

# %%
##To view the last 10 rows of dataset 
data.tail(10)
# Out:
#     Col1   Col2    Col3 Col4 Col5 Col6 Col7   Col8 Col9 Col10  Col11 Col12  \
# 680    b  19.50   0.290    u    g    k    v  0.290    f     f      0     f
# 681    b  27.83   1.000    y    p    d    h  3.000    f     f      0     f
# 682    b  17.08   3.290    u    g    i    v  0.335    f     f      0     t
# 683    b  36.42   0.750    y    p    d    v  0.585    f     f      0     f
# 684    b  40.58   3.290    u    g    m    v  3.500    f     f      0     t
# 685    b  21.08  10.085    y    p    e    h  1.250    f     f      0     f
# 686    a  22.67   0.750    u    g    c    v  2.000    f     t      2     t
# 687    a  25.25  13.500    y    p   ff   ff  2.000    f     t      1     t
# 688    b  17.92   0.205    u    g   aa    v  0.040    f     f      0     f
# 689    b  35.00   3.375    u    g    c    h  8.290    f     f      0     t
#
#     Col13  Col14  Col15 Col16
# 680     g  00280    364     -
# 681     g  00176    537     -
# 682     g  00140      2     -
# ...

# %% [markdown]
# 3.	Replace the ‘?’ with Not-a-Number

# %%
#To replace ? with Not-an-Number (np.nan)
data = data.replace('?',np.nan)

# %%
data
# Out:
#     Col1   Col2    Col3 Col4 Col5 Col6 Col7  Col8 Col9 Col10  Col11 Col12  \
# 0      b  30.83   0.000    u    g    w    v  1.25    t     t      1     f
# 1      a  58.67   4.460    u    g    q    h  3.04    t     t      6     f
# 2      a  24.50   0.500    u    g    q    h  1.50    t     f      0     f
# 3      b  27.83   1.540    u    g    w    v  3.75    t     t      5     t
# 4      b  20.17   5.625    u    g    w    v  1.71    t     f      0     f
# ..   ...    ...     ...  ...  ...  ...  ...   ...  ...   ...    ...   ...
# 685    b  21.08  10.085    y    p    e    h  1.25    f     f      0     f
# 686    a  22.67   0.750    u    g    c    v  2.00    f     t      2     t
# 687    a  25.25  13.500    y    p   ff   ff  2.00    f     t      1     t
# 688    b  17.92   0.205    u    g   aa    v  0.04    f     f      0     f
# 689    b  35.00   3.375    u    g    c    h  8.29    f     f      0     t
#
#     Col13  Col14  Col15 Col16
# 0       g  00202      0     +
# ...

# %% [markdown]
# 4.	Comment on the datatype of variables

# %%
#To view the different Data Types of the variables present in the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 16 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Col1    678 non-null    object
#  1   Col2    678 non-null    object
#  2   Col3    690 non-null    float64
#  3   Col4    684 non-null    object
#  4   Col5    684 non-null    object
#  5   Col6    681 non-null    object
#  6   Col7    681 non-null    object
#  7   Col8    690 non-null    float64
#  8   Col9    690 non-null    object
#  9   Col10   690 non-null    object
#  10  Col11   690 non-null    int64
#  11  Col12   690 non-null    object
#  12  Col13   690 non-null    object
#  13  Col14   677 non-null    object
#  14  Col15   690 non-null    int64
#  15  Col16   690 non-null    object
# dtypes: float64(2), int64(2), object(12)
# memory usage: 86.4+ KB

# %% [markdown]
# It can be observed that there are 3 different data types of the
# variables present in the crx.data dataset which are:-
#  1) float64(2), 2) int64(2), 3) object(12)

# %%
#Recasting variables Col2 and Col14 to their correct data types
data['Col2'] = data['Col2'].astype('float')
data['Col14'] = data['Col14'].astype('float')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 16 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Col1    678 non-null    object
#  1   Col2    678 non-null    float64
#  2   Col3    690 non-null    float64
#  3   Col4    684 non-null    object
#  4   Col5    684 non-null    object
#  5   Col6    681 non-null    object
#  6   Col7    681 non-null    object
#  7   Col8    690 non-null    float64
#  8   Col9    690 non-null    object
#  9   Col10   690 non-null    object
#  10  Col11   690 non-null    int64
#  11  Col12   690 non-null    object
#  12  Col13   690 non-null    object
#  13  Col14   677 non-null    float64
#  14  Col15   690 non-null    int64
#  15  Col16   690 non-null    object
# dtypes: float64(4), int64(2), object(10)
# memory usage: 86.4+ KB

# %% [markdown]
# 5.	The col16 has + and -, replace them ‘P’ and ‘N’ respectively

# %%
#To encode Col16 values from + and - to 'P' and 'N' respectively
data['Col16'] = data['Col16'].map({'+':'P', '-':'N'})

# %%
data
# Out:
#     Col1   Col2    Col3 Col4 Col5 Col6 Col7  Col8 Col9 Col10  Col11 Col12  \
# 0      b  30.83   0.000    u    g    w    v  1.25    t     t      1     f
# 1      a  58.67   4.460    u    g    q    h  3.04    t     t      6     f
# 2      a  24.50   0.500    u    g    q    h  1.50    t     f      0     f
# 3      b  27.83   1.540    u    g    w    v  3.75    t     t      5     t
# 4      b  20.17   5.625    u    g    w    v  1.71    t     f      0     f
# ..   ...    ...     ...  ...  ...  ...  ...   ...  ...   ...    ...   ...
# 685    b  21.08  10.085    y    p    e    h  1.25    f     f      0     f
# 686    a  22.67   0.750    u    g    c    v  2.00    f     t      2     t
# 687    a  25.25  13.500    y    p   ff   ff  2.00    f     t      1     t
# 688    b  17.92   0.205    u    g   aa    v  0.04    f     f      0     f
# 689    b  35.00   3.375    u    g    c    h  8.29    f     f      0     t
#
#     Col13  Col14  Col15 Col16
# 0       g  202.0      0     P
# ...

# %% [markdown]
# 6.	Find and display the number of  variables of type ‘Object’

# %%
#To find and display the Number of Object type variables present in the dataset
obj_columns = [i for i in data.columns if data[i].dtypes == 'O']
print(obj_columns)
# Out:
# ['Col1', 'Col4', 'Col5', 'Col6', 'Col7', 'Col9', 'Col10', 'Col12', 'Col13', 'Col16']

# %%
data[obj_columns]
# Out:
#     Col1 Col4 Col5 Col6 Col7 Col9 Col10 Col12 Col13 Col16
# 0      b    u    g    w    v    t     t     f     g     P
# 1      a    u    g    q    h    t     t     f     g     P
# 2      a    u    g    q    h    t     f     f     g     P
# 3      b    u    g    w    v    t     t     t     g     P
# 4      b    u    g    w    v    t     f     f     s     P
# ..   ...  ...  ...  ...  ...  ...   ...   ...   ...   ...
# 685    b    y    p    e    h    f     f     f     g     N
# 686    a    u    g    c    v    f     t     t     g     N
# 687    a    y    p   ff   ff    f     t     t     g     N
# 688    b    u    g   aa    v    f     f     f     g     N
# 689    b    u    g    c    h    f     f     t     g     N
#
# [690 rows x 10 columns]

# %% [markdown]
# Performing Feature Engineering on loan.csv dataset

# %%
#Loading the data to DataFrame using Pandas
data1 = pd.read_csv('loan.csv')

# %%
data1
# Out:
#       customer_id  disbursed_amount  interest market     employment  \
# 0               0           23201.5   15.4840      C        Teacher
# 1               1            7425.0   11.2032      B     Accountant
# 2               2           11150.0    8.5100      A   Statistician
# 3               3            7600.0    5.8656      A          Other
# 4               4           31960.0   18.7392      E     Bus driver
# ...           ...               ...       ...    ...            ...
# 9995         9995           23750.0   11.0019      B  Civil Servant
# 9996         9996           11880.0   10.4923      B  Civil Servant
# 9997         9997           19950.0    8.4364      B     Accountant
# 9998         9998            4850.0   13.6409      C     Bus driver
# 9999         9999           25584.0   17.1456      D     Accountant
#
#      time_employed householder    income date_issued  target  \
# 0        <=5 years        RENT   84600.0  2013-06-11       0
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_id             10000 non-null  int64
#  1   disbursed_amount        10000 non-null  float64
#  2   interest                10000 non-null  float64
#  3   market                  10000 non-null  object
#  4   employment              9389 non-null   object
#  5   time_employed           9471 non-null   object
#  6   householder             10000 non-null  object
#  7   income                  10000 non-null  float64
#  8   date_issued             10000 non-null  object
#  9   target                  10000 non-null  int64
#  10  loan_purpose            10000 non-null  object
#  11  number_open_accounts    10000 non-null  float64
#  12  date_last_payment       10000 non-null  object
#  13  number_credit_lines_12  238 non-null    float64
# ...

# %% [markdown]
# 1.	Display the mean of any two variables with continuous values

# %%
#To display the Statistical Parameter Mean of the variable 'disbursed_amount' 
#which consists of  continuous values
m1=data1['disbursed_amount'].mean()
print('Mean of column disbursed_amount = '+str(m1))
# Out:
# Mean of column disbursed_amount = 14132.2755

# %%
#To display the Statistical Parameter Mean of the variable 'interest' 
#which consists of  continuous values 
m3=data1['interest'].mean()
print('Mean of column interest = '+str(m3))
# Out:
# Mean of column interest = 12.678819440000039

# %% [markdown]
# 2.	Print the number of discrete variables

# %%
#Recasting variable 'number_open_accounts' to its correct data type
data1['number_open_accounts'] = data1['number_open_accounts'].astype('int')

# %%
num = ['int16', 'int32', 'int64']
df1 = data1.select_dtypes(include=num)

# %%
#To print the number of discrete variables present in the dataset
df1
# Out:
#       customer_id  target  number_open_accounts
# 0               0       0                     4
# 1               1       0                    13
# 2               2       0                     8
# 3               3       0                    20
# 4               4       0                    14
# ...           ...     ...                   ...
# 9995         9995       0                    12
# 9996         9996       0                    17
# 9997         9997       0                     9
# 9998         9998       0                    26
# 9999         9999       0                     5
#
# [10000 rows x 3 columns]

# %% [markdown]
# It can be observed that there are 3 Discrete Variables present in the loan.csv dataset which are:-
# 1) 'customer_id'  2) 'target'  3) 'number_open_accounts'

# %% [markdown]
# 3.	Display the unique values of two variables with discrete values

# %%
#To display the unique values of the discrete variable 'number_open_accounts'
data1['number_open_accounts'].unique()
# Out:
# array([ 4, 13,  8, 20, 14,  5,  9, 18, 16, 17, 12, 15,  6, 10, 11,  7, 21,
#        19, 26,  2, 22, 27, 23, 25, 24, 28,  3, 30, 41, 32, 33, 31, 29, 37,
#        49, 34, 35, 38,  1, 36, 42, 47, 40, 44, 43])

# %%
#To display the unique values of the discrete variable 'target'
data1['target'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
#To display the unique values of the discrete variable 'customer_id'
data1['customer_id'].unique()
# Out:
# array([   0,    1,    2, ..., 9997, 9998, 9999], dtype=int64)

# %% [markdown]
# 4.	Display the Month with most of loans issued date

# %%
#To view the unique values of the variable 'date_issued'
data1['date_issued'].unique()
# Out:
# array(['2013-06-11', '2014-05-08', '2013-10-26', ..., '2010-08-22',
#        '2009-06-02', '2010-01-14'], dtype=object)

# %%
#Converting and storing 'date_issued' variable in date-time format as 'date_issued_dt' 
#variable appended in the dataset
data1['date_issued_dt'] = pd.to_datetime(data1['date_issued'])
data1.head()
# Out:
#    customer_id  disbursed_amount  interest market    employment time_employed  \
# 0            0           23201.5   15.4840      C       Teacher     <=5 years
# 1            1            7425.0   11.2032      B    Accountant     <=5 years
# 2            2           11150.0    8.5100      A  Statistician     <=5 years
# 3            3            7600.0    5.8656      A         Other     <=5 years
# 4            4           31960.0   18.7392      E    Bus driver      >5 years
#
#   householder    income date_issued  target        loan_purpose  \
# 0        RENT   84600.0  2013-06-11       0  Debt consolidation
# 1       OWNER  102000.0  2014-05-08       0        Car purchase
# 2        RENT   69840.0  2013-10-26       0  Debt consolidation
# 3        RENT  100386.0  2015-08-20       0  Debt consolidation
# 4        RENT   95040.0  2014-07-22       0  Debt consolidation
#
#    number_open_accounts date_last_payment  number_credit_lines_12  \
# ...

# %%
#To extract the Months from the date-time values of 'date_issued_dt' Variable
data1['month'] = data1['date_issued_dt'].dt.month

# %%
#To display the number of occurrence of each unique value of the variable 'month'
data1['month'].value_counts()
# Out:
# 10    1277
# 7     1066
# 11    1017
# 12     882
# 8      852
# 4      816
# 5      749
# 9      734
# 6      700
# 1      700
# 3      623
# 2      584
# Name: month, dtype: int64

# %%
print(data1.groupby('month').count())
# Out:
#        customer_id  disbursed_amount  interest  market  employment  \
# month
# 1              700               700       700     700         655
# 2              584               584       584     584         536
# 3              623               623       623     623         588
# 4              816               816       816     816         779
# 5              749               749       749     749         704
# 6              700               700       700     700         665
# 7             1066              1066      1066    1066        1006
# 8              852               852       852     852         792
# 9              734               734       734     734         687
# 10            1277              1277      1277    1277        1212
# 11            1017              1017      1017    1017         944
# 12             882               882       882     882         821
#
#        time_employed  householder  income  date_issued  target  loan_purpose  \
# month
# ...

# %% [markdown]
# It can be observed that the 10 th Month i.e, the Month of October has the highest/most numbers of Loans issued date

# %% [markdown]
# 5.	Display the count of ‘Teacher’ who are ‘Owners’

# %%
#To display the number of occurrence of each value of the variable 'employment'
data1['employment'].value_counts()
# Out:
# Civil Servant         884
# Nurse                 880
# Bus driver            874
# Other                 863
# Teacher               861
# Accountant            852
# Statistician          852
# Secretary             846
# Dentist               844
# Taxi driver           825
# Software developer    808
# Name: employment, dtype: int64

# %%
#To display the number of occurrence of each value of the variable 'householder'
data1['householder'].value_counts()
# Out:
# MORTGAGE    4957
# RENT        4055
# OWNER        988
# Name: householder, dtype: int64

# %%
#To display the frequency/count of all the combinations of the values of the two
#variables 'employment' and 'householder' of the dataset
data1['Emp_Hous'] = data1['employment'].str.cat(data1['householder'],sep=" ")
print(data1['Emp_Hous'].value_counts())
# Out:
# Nurse MORTGAGE                 444
# Accountant MORTGAGE            440
# Secretary MORTGAGE             432
# Taxi driver MORTGAGE           429
# Statistician MORTGAGE          426
# Other MORTGAGE                 425
# Civil Servant MORTGAGE         424
# Teacher MORTGAGE               421
# Bus driver MORTGAGE            418
# Dentist MORTGAGE               418
# Software developer MORTGAGE    417
# Civil Servant RENT             371
# Teacher RENT                   371
# Bus driver RENT                360
# Nurse RENT                     358
# Dentist RENT                   355
# Secretary RENT                 355
# Other RENT                     353
# Statistician RENT              342
# Accountant RENT                322
# Taxi driver RENT               316
# Software developer RENT        315
# Bus driver OWNER                96
# Accountant OWNER                90
# Civil Servant OWNER             89
# Other OWNER                     85
# Statistician OWNER              84
# ...

# %%
#Selecting all the rows of the dataset having 'employment' variable value eqaul to 'TEACHER'
data2 = data1[data1['employment']=='Teacher']

# %%
#Selecting all the rows of the dataset having 'householder' variable value eqaul to 'OWNER'
data3 = data2[data2['householder']=='OWNER']

# %%
#To  Display the count of ‘Teacher’ who are ‘Owners’
data3['Teach_Own'] = data3['householder'].str.cat(data3['employment'],sep=" ")
print(data3['Teach_Own'].value_counts())
# Out:
# OWNER Teacher    69
# Name: Teach_Own, dtype: int64
# <ipython-input-217-ebf08aafce19>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3['Teach_Own'] = data3['householder'].str.cat(data3['employment'],sep=" ")

# %% [markdown]
# It can be observed that the count of 'Teacher' who are 'Owners' is 69

# %% [markdown]
# 6.	Display the ‘Employment’ of customers who mostly ‘Rent’

# %%
#To display the number of occurrence of each value of the variable 'employment'
data1['employment'].value_counts()
# Out:
# Civil Servant         884
# Nurse                 880
# Bus driver            874
# Other                 863
# Teacher               861
# Accountant            852
# Statistician          852
# Secretary             846
# Dentist               844
# Taxi driver           825
# Software developer    808
# Name: employment, dtype: int64

# %%
#To display the number of occurrence of each value of the variable 'householder'
data1['householder'].value_counts()
# Out:
# MORTGAGE    4957
# RENT        4055
# OWNER        988
# Name: householder, dtype: int64

# %%
#To display the frequency/count of all the combinations of the values of the two
#variables 'employment' and 'householder' of the dataset
data1['Emp_Hous'] = data1['employment'].str.cat(data1['householder'],sep=" ")
print(data1['Emp_Hous'].value_counts())
# Out:
# Nurse MORTGAGE                 444
# Accountant MORTGAGE            440
# Secretary MORTGAGE             432
# Taxi driver MORTGAGE           429
# Statistician MORTGAGE          426
# Other MORTGAGE                 425
# Civil Servant MORTGAGE         424
# Teacher MORTGAGE               421
# Bus driver MORTGAGE            418
# Dentist MORTGAGE               418
# Software developer MORTGAGE    417
# Civil Servant RENT             371
# Teacher RENT                   371
# Bus driver RENT                360
# Nurse RENT                     358
# Dentist RENT                   355
# Secretary RENT                 355
# Other RENT                     353
# Statistician RENT              342
# Accountant RENT                322
# Taxi driver RENT               316
# Software developer RENT        315
# Bus driver OWNER                96
# Accountant OWNER                90
# Civil Servant OWNER             89
# Other OWNER                     85
# Statistician OWNER              84
# ...

# %%
#Selecting all the rows of the dataset having 'householder' variable value eqaul to 'RENT'
data4 = data1[data1['householder']=='RENT']

# %%
#To display the frequency/count of all the combinations of the values of the two
#variables 'employment' and 'householder' equals to 'RENT' of the dataset

data4['Rent_Emp'] = data4['householder'].str.cat(data4['employment'],sep=" ")

c = data4['Rent_Emp'].value_counts()
print(c)
# Out:
# RENT Civil Servant         371
# RENT Teacher               371
# RENT Bus driver            360
# RENT Nurse                 358
# RENT Secretary             355
# RENT Dentist               355
# RENT Other                 353
# RENT Statistician          342
# RENT Accountant            322
# RENT Taxi driver           316
# RENT Software developer    315
# Name: Rent_Emp, dtype: int64
# <ipython-input-222-118e505d17d0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data4['Rent_Emp'] = data4['householder'].str.cat(data4['employment'],sep=" ")

# %%
c.max()
# Out:
# 371

# %%
emp = ['Teacher', 'Civil Servant']
data5 = data4[data4['employment'].isin(emp) ]

# %%
# To Display the ‘Employment’ of customers who mostly ‘Rent’

data5['Emp-max_rent']= data5['householder'].str.cat(data5['employment'],sep=" ")
print(data5['Emp-max_rent'].value_counts())
# Out:
# RENT Civil Servant    371
# RENT Teacher          371
# Name: Emp-max_rent, dtype: int64
# <ipython-input-225-e49caf6fc9e0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data5['Emp-max_rent']= data5['householder'].str.cat(data5['employment'],sep=" ")

# %% [markdown]
# It can be observed that the maximum count of 'Employment'  who are 'Owners' is 371 and
# the employment type with this maximum value are 'Teacher' and  'Civil Servant'
